# %%
import pandas as pd

# %%
df= pd.read_excel(r"C:\Users\Monsruti Devi\Documents\DRUG DISCOVERY PROJECT\Book1.xlsx", header= None)
df
# Out:
#                                   0                                       1  \
# 0                           Column1                                 Column2
# 1                               NaN                                     NaN
# 2                             S No.                   CHEMICAL CONSTITUENTS
# 3                                1.                          Bruceine B^1,2
# 4                                2.                          Bruceine D^1,2
# 5                                3.                           Brusatol^1,2
# 6                               4.                         Bruceoside B^1,2
# 7                                5.                      Yadanziolide A^1,2
# 8                                6.                        Soulameanone 1,2
# 9                                7.             11-Hydroxycanthin-6-one 1,2
# 10                               8.                       Bruceolline A 1,2
# ...

# %%
df2= df.iloc[26,1]= "glucopyranosylcanthin-6-one 1,2"
df3= df.iloc[28,1]= "glucopyranosylcanthin-6-one 1,2"
df
# Out:
#                                   0                                       1  \
# 0                           Column1                                 Column2
# 1                               NaN                                     NaN
# 2                             S No.                   CHEMICAL CONSTITUENTS
# 3                                1.                          Bruceine B^1,2
# 4                                2.                          Bruceine D^1,2
# 5                                3.                           Brusatol^1,2
# 6                               4.                         Bruceoside B^1,2
# 7                                5.                      Yadanziolide A^1,2
# 8                                6.                        Soulameanone 1,2
# 9                                7.             11-Hydroxycanthin-6-one 1,2
# 10                               8.                       Bruceolline A 1,2
# ...

# %%
df4= df.iloc[26,0]= "26"
df5= df.iloc[28,0]= "28"
df
# Out:
#           0                                       1  \
# 0   Column1                                 Column2
# 1       NaN                                     NaN
# 2     S No.                   CHEMICAL CONSTITUENTS
# 3        1.                          Bruceine B^1,2
# 4        2.                          Bruceine D^1,2
# 5        3.                           Brusatol^1,2
# 6       4.                         Bruceoside B^1,2
# 7        5.                      Yadanziolide A^1,2
# 8        6.                        Soulameanone 1,2
# 9        7.             11-Hydroxycanthin-6-one 1,2
# 10       8.                       Bruceolline A 1,2
# 11       9.                       Bruceolline B 1,4
# 12      10.                       Bruceolline C 1,2
# 13      11.                       Bruceolline D 1,2
# 14      12.                       Bruceolline E 1,2
# 15      13.                       Bruceolline F 1,2
# 16      14.                       Bruceolline G 1,2
# ...

# %%
df6= df.iloc[2:]
df6
# Out:
#         0                                       1  \
# 2   S No.                   CHEMICAL CONSTITUENTS
# 3      1.                          Bruceine B^1,2
# 4      2.                          Bruceine D^1,2
# 5      3.                           Brusatol^1,2
# 6     4.                         Bruceoside B^1,2
# 7      5.                      Yadanziolide A^1,2
# 8      6.                        Soulameanone 1,2
# 9      7.             11-Hydroxycanthin-6-one 1,2
# 10     8.                       Bruceolline A 1,2
# 11     9.                       Bruceolline B 1,4
# 12    10.                       Bruceolline C 1,2
# 13    11.                       Bruceolline D 1,2
# 14    12.                       Bruceolline E 1,2
# 15    13.                       Bruceolline F 1,2
# 16    14.                       Bruceolline G 1,2
# 17    15.         5,11-Dimethoxycanthin-6-one 1,2
# 18    16.       11-Hydroxycanthin-6-one N-oxide 2
# 19    17.       11-hydroxy-1-methoxycanthin-6 1,5
# ...

# %%
df7= df.reset_index(drop= True)
df8= df[0]= range(1, len(df)+ 1)
df
# Out:
#      0                                       1  \
# 0    1                                 Column2
# 1    2                                     NaN
# 2    3                   CHEMICAL CONSTITUENTS
# 3    4                          Bruceine B^1,2
# 4    5                          Bruceine D^1,2
# 5    6                           Brusatol^1,2
# 6    7                        Bruceoside B^1,2
# 7    8                      Yadanziolide A^1,2
# 8    9                        Soulameanone 1,2
# 9   10             11-Hydroxycanthin-6-one 1,2
# 10  11                       Bruceolline A 1,2
# 11  12                       Bruceolline B 1,4
# 12  13                       Bruceolline C 1,2
# 13  14                       Bruceolline D 1,2
# 14  15                       Bruceolline E 1,2
# 15  16                       Bruceolline F 1,2
# 16  17                       Bruceolline G 1,2
# 17  18         5,11-Dimethoxycanthin-6-one 1,2
# 18  19       11-Hydroxycanthin-6-one N-oxide 2
# ...

# %%
df9= df.iloc[2:]
df9
# Out:
#      0                                       1  \
# 2    3                   CHEMICAL CONSTITUENTS
# 3    4                          Bruceine B^1,2
# 4    5                          Bruceine D^1,2
# 5    6                           Brusatol^1,2
# 6    7                        Bruceoside B^1,2
# 7    8                      Yadanziolide A^1,2
# 8    9                        Soulameanone 1,2
# 9   10             11-Hydroxycanthin-6-one 1,2
# 10  11                       Bruceolline A 1,2
# 11  12                       Bruceolline B 1,4
# 12  13                       Bruceolline C 1,2
# 13  14                       Bruceolline D 1,2
# 14  15                       Bruceolline E 1,2
# 15  16                       Bruceolline F 1,2
# 16  17                       Bruceolline G 1,2
# 17  18         5,11-Dimethoxycanthin-6-one 1,2
# 18  19       11-Hydroxycanthin-6-one N-oxide 2
# 19  20       11-hydroxy-1-methoxycanthin-6 1,5
# 20  21       1-(Hydroxymethyl) ?-carboline 1,5
# ...

# %%
# Out:
#      0                                       1  \
# 0    1                                 Column2
# 1    2                                     NaN
# 2    3                   CHEMICAL CONSTITUENTS
# 3    4                          Bruceine B^1,2
# 4    5                          Bruceine D^1,2
# 5    6                           Brusatol^1,2
# 6    7                        Bruceoside B^1,2
# 7    8                      Yadanziolide A^1,2
# 8    9                        Soulameanone 1,2
# 9   10             11-Hydroxycanthin-6-one 1,2
# 10  11                       Bruceolline A 1,2
# 11  12                       Bruceolline B 1,4
# 12  13                       Bruceolline C 1,2
# 13  14                       Bruceolline D 1,2
# 14  15                       Bruceolline E 1,2
# 15  16                       Bruceolline F 1,2
# 16  17                       Bruceolline G 1,2
# 17  18         5,11-Dimethoxycanthin-6-one 1,2
# 18  19       11-Hydroxycanthin-6-one N-oxide 2
# ...
