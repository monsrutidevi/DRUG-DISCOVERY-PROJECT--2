# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\Monsruti Devi\Documents\DRUG DISCOVERY PROJECT\javanica datase.csv")
df
# Out:
#      0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1            Bruceine A   CHEMBL250451
# 1    2            Bruceine B   CHEMBL140809
# 2    3            Bruceine C   CHEMBL455759
# 3    4            Bruceine D   CHEMBL477693
# 4    5            Bruceine E  CHEMBL2037038
# ..  ..                   ...            ...
# 76  93         Brujavanone J            NaN
# 77  94         Brujavanone K            NaN
# 78  95         Brujavanone L            NaN
# 79  96         Brujavanone M            NaN
# 80  97         Brujavanone N            NaN
#
#                                                SMILES  standard_value  \
# 0   COC(=O)[C@@]12OC[C@]34[C@H]([C@@H](O)[C@@H]1O)...           0.004
# 1   COC(=O)[C@@]12OC[C@]34[C@H]([C@@H](O)[C@@H]1O)...           0.893
# 2   COC(=O)[C@]12OC[C@]34[C@H]([C@@H](O)[C@@H]1O)[...           0.107
# 3   CC1=CC(=O)[C@@H](O)[C@]2(C)[C@H]3[C@@H](O)[C@H...           0.835
# 4   CC1=C[C@H](O)[C@@H](O)[C@]2(C)[C@H]3[C@@H](O)[...        5000.000
# ...

# %%
# # Set options to display all rows and columns
# df= pd.set_option('display.max_rows', None)
# df= pd.set_option('display.max_columns', None)
# df= pd.set_option('display.max_colwidth', None) # To prevent truncation of long text in cells

# # Display your DataFrame
# df

# %%
df
# Out:
#      0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1            Bruceine A   CHEMBL250451
# 1    2            Bruceine B   CHEMBL140809
# 2    3            Bruceine C   CHEMBL455759
# 3    4            Bruceine D   CHEMBL477693
# 4    5            Bruceine E  CHEMBL2037038
# ..  ..                   ...            ...
# 76  93         Brujavanone J            NaN
# 77  94         Brujavanone K            NaN
# 78  95         Brujavanone L            NaN
# 79  96         Brujavanone M            NaN
# 80  97         Brujavanone N            NaN
#
#                                                SMILES  standard_value  \
# 0   COC(=O)[C@@]12OC[C@]34[C@H]([C@@H](O)[C@@H]1O)...           0.004
# 1   COC(=O)[C@@]12OC[C@]34[C@H]([C@@H](O)[C@@H]1O)...           0.893
# 2   COC(=O)[C@]12OC[C@]34[C@H]([C@@H](O)[C@@H]1O)[...           0.107
# 3   CC1=CC(=O)[C@@H](O)[C@]2(C)[C@H]3[C@@H](O)[C@H...           0.835
# 4   CC1=C[C@H](O)[C@@H](O)[C@]2(C)[C@H]3[C@@H](O)[...        5000.000
# ...

# %%
df = df.dropna(subset=["SMILES"])
df
# Out:
#      0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1            Bruceine A   CHEMBL250451
# 1    2            Bruceine B   CHEMBL140809
# 2    3            Bruceine C   CHEMBL455759
# 3    4            Bruceine D   CHEMBL477693
# 4    5            Bruceine E  CHEMBL2037038
# 6    8            Bruceine H  CHEMBL2037039
# 8   10            Bruceine J   CHEMBL399970
# 15  17        Javanicolide C   CHEMBL443898
# 16  18        Javanicolide D   CHEMBL503843
# 17  19        Javanicolide E  CHEMBL2037041
# 18  20        Javanicolide H  CHEMBL2037037
# 19  21        Javanicoside B   CHEMBL503591
# 20  22        Javanicoside C   CHEMBL446883
# 21  23        Javanicoside D   CHEMBL451166
# 22  24        Javanicoside E   CHEMBL508819
# 23  25        Javanicoside F   CHEMBL510116
# 31  33        Yadanzioside A  CHEMBL2367704
# 32  34        Yadanzioside B  CHEMBL2367700
# 33  35        Yadanzioside C   CHEMBL499465
# 34  36        Yadanzioside E  CHEMBL2367698
# ...

# %%
new_compounds= pd.DataFrame({"CHEMICAL CONSTITUENTS":["Bruceolline E","Bruceolline F","Canthin-6-one"],
                              "ChEMBL_ID": ["CHEMBL1922996","CHEMBL1922997","CHEMBL156897"],
                              "SMILES":["CC1(C)C(=O)C(=O)c2c1[nH]c1ccccc21", "CC(C)(O)[C@@H](O)Cc1cn([C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)c2ccccc12", "O=c1ccc2nccc3c4ccccc4n1c23"],
                               "standard_value":["10000.0", "10000.0", "1.11"],
                               "units": ["nM", "nM", "ug.mL-1"],
                               "bioactivity_class": ["Intermediate", "Intermediate", "Active"]})
df= pd.concat([df, new_compounds], ignore_index= True)

# %%
df
# Out:
#        0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1.0            Bruceine A   CHEMBL250451
# 1    2.0            Bruceine B   CHEMBL140809
# 2    3.0            Bruceine C   CHEMBL455759
# 3    4.0            Bruceine D   CHEMBL477693
# 4    5.0            Bruceine E  CHEMBL2037038
# 5    8.0            Bruceine H  CHEMBL2037039
# 6   10.0            Bruceine J   CHEMBL399970
# 7   17.0        Javanicolide C   CHEMBL443898
# 8   18.0        Javanicolide D   CHEMBL503843
# 9   19.0        Javanicolide E  CHEMBL2037041
# 10  20.0        Javanicolide H  CHEMBL2037037
# 11  21.0        Javanicoside B   CHEMBL503591
# 12  22.0        Javanicoside C   CHEMBL446883
# 13  23.0        Javanicoside D   CHEMBL451166
# 14  24.0        Javanicoside E   CHEMBL508819
# 15  25.0        Javanicoside F   CHEMBL510116
# 16  33.0        Yadanzioside A  CHEMBL2367704
# 17  34.0        Yadanzioside B  CHEMBL2367700
# 18  35.0        Yadanzioside C   CHEMBL499465
# ...

# %%
df.to_csv("javanica done.csv", index= False)
