# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client
# Out:
# C:\Users\Monsruti Devi\AppData\Local\Programs\Python\Python313\Lib\site-packages\chembl_webresource_client\__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __version__ = __import__('pkg_resources').get_distribution('chembl_webresource_client').version

# %%
target = new_client.target
target_query = target.search('brucea')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
# Empty DataFrame
# Columns: []
# Index: []
