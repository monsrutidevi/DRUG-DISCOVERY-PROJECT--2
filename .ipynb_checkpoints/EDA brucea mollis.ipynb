# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\Monsruti Devi\Documents\DRUG DISCOVERY PROJECT\javanica done.csv")
df
# Out:
#        0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1.0            Bruceine A   CHEMBL250451
# 1    2.0            Bruceine B   CHEMBL140809
# 2    3.0            Bruceine C   CHEMBL455759
# 3    4.0            Bruceine D   CHEMBL477693
# 4    5.0            Bruceine E  CHEMBL2037038
# 5    8.0            Bruceine H  CHEMBL2037039
# 6   10.0            Bruceine J   CHEMBL399970
# 7   17.0        Javanicolide C   CHEMBL443898
# 8   18.0        Javanicolide D   CHEMBL503843
# 9   19.0        Javanicolide E  CHEMBL2037041
# 10  20.0        Javanicolide H  CHEMBL2037037
# 11  21.0        Javanicoside B   CHEMBL503591
# 12  22.0        Javanicoside C   CHEMBL446883
# 13  23.0        Javanicoside D   CHEMBL451166
# 14  24.0        Javanicoside E   CHEMBL508819
# 15  25.0        Javanicoside F   CHEMBL510116
# 16  33.0        Yadanzioside A  CHEMBL2367704
# 17  34.0        Yadanzioside B  CHEMBL2367700
# 18  35.0        Yadanzioside C   CHEMBL499465
# ...

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors
import pandas as pd

def lipinski(smiles):
    mol = Chem.MolFromSmiles(smiles)
    
    mw = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)

    return pd.Series([mw, logp, hbd, hba])

df[["MW","LogP","HBD","HBA"]] = df["SMILES"].apply(lipinski)
df
# Out:
#        0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1.0            Bruceine A   CHEMBL250451
# 1    2.0            Bruceine B   CHEMBL140809
# 2    3.0            Bruceine C   CHEMBL455759
# 3    4.0            Bruceine D   CHEMBL477693
# 4    5.0            Bruceine E  CHEMBL2037038
# 5    8.0            Bruceine H  CHEMBL2037039
# 6   10.0            Bruceine J   CHEMBL399970
# 7   17.0        Javanicolide C   CHEMBL443898
# 8   18.0        Javanicolide D   CHEMBL503843
# 9   19.0        Javanicolide E  CHEMBL2037041
# 10  20.0        Javanicolide H  CHEMBL2037037
# 11  21.0        Javanicoside B   CHEMBL503591
# 12  22.0        Javanicoside C   CHEMBL446883
# 13  23.0        Javanicoside D   CHEMBL451166
# 14  24.0        Javanicoside E   CHEMBL508819
# 15  25.0        Javanicoside F   CHEMBL510116
# 16  33.0        Yadanzioside A  CHEMBL2367704
# 17  34.0        Yadanzioside B  CHEMBL2367700
# 18  35.0        Yadanzioside C   CHEMBL499465
# ...

# %%
import numpy as np

def convert_to_molar(row):
    
    value = row['standard_value']
    unit = row['units']
    mw = row['MW']
    
    if pd.isna(value):
        return None
    
    # nM → M
    if unit == 'nM':
        return value * 1e-9
    
    # µM → M
    elif unit == 'uM':
        return value * 1e-6
    
    # µg/mL → M
    elif unit in ['ug.mL-1','µg/mL','ug/mL']:
        return (value * 1e-6) / mw
    
    else:
        return None


# convert to molar
df['IC50_M'] = df.apply(convert_to_molar, axis=1)

# calculate pIC50
df['pIC50'] = -np.log10(df['IC50_M'])
df
# Out:
#        0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1.0            Bruceine A   CHEMBL250451
# 1    2.0            Bruceine B   CHEMBL140809
# 2    3.0            Bruceine C   CHEMBL455759
# 3    4.0            Bruceine D   CHEMBL477693
# 4    5.0            Bruceine E  CHEMBL2037038
# 5    8.0            Bruceine H  CHEMBL2037039
# 6   10.0            Bruceine J   CHEMBL399970
# 7   17.0        Javanicolide C   CHEMBL443898
# 8   18.0        Javanicolide D   CHEMBL503843
# 9   19.0        Javanicolide E  CHEMBL2037041
# 10  20.0        Javanicolide H  CHEMBL2037037
# 11  21.0        Javanicoside B   CHEMBL503591
# 12  22.0        Javanicoside C   CHEMBL446883
# 13  23.0        Javanicoside D   CHEMBL451166
# 14  24.0        Javanicoside E   CHEMBL508819
# 15  25.0        Javanicoside F   CHEMBL510116
# 16  33.0        Yadanzioside A  CHEMBL2367704
# 17  34.0        Yadanzioside B  CHEMBL2367700
# 18  35.0        Yadanzioside C   CHEMBL499465
# ...

# %%
def norm_value(input):
    norm = []
    
    for i in input:
        if float(i) > 100000000:
            i = 100000000
        norm.append(float(i))
        
    return norm

df["standard_value_norm"] = norm_value(df["standard_value"])
df
# Out:
#        0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1.0            Bruceine A   CHEMBL250451
# 1    2.0            Bruceine B   CHEMBL140809
# 2    3.0            Bruceine C   CHEMBL455759
# 3    4.0            Bruceine D   CHEMBL477693
# 4    5.0            Bruceine E  CHEMBL2037038
# 5    8.0            Bruceine H  CHEMBL2037039
# 6   10.0            Bruceine J   CHEMBL399970
# 7   17.0        Javanicolide C   CHEMBL443898
# 8   18.0        Javanicolide D   CHEMBL503843
# 9   19.0        Javanicolide E  CHEMBL2037041
# 10  20.0        Javanicolide H  CHEMBL2037037
# 11  21.0        Javanicoside B   CHEMBL503591
# 12  22.0        Javanicoside C   CHEMBL446883
# 13  23.0        Javanicoside D   CHEMBL451166
# 14  24.0        Javanicoside E   CHEMBL508819
# 15  25.0        Javanicoside F   CHEMBL510116
# 16  33.0        Yadanzioside A  CHEMBL2367704
# 17  34.0        Yadanzioside B  CHEMBL2367700
# 18  35.0        Yadanzioside C   CHEMBL499465
# ...

# %%
df = df[df.bioactivity_class != "Intermediate"]
df
# Out:
#        0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1.0            Bruceine A   CHEMBL250451
# 1    2.0            Bruceine B   CHEMBL140809
# 2    3.0            Bruceine C   CHEMBL455759
# 3    4.0            Bruceine D   CHEMBL477693
# 6   10.0            Bruceine J   CHEMBL399970
# 7   17.0        Javanicolide C   CHEMBL443898
# 8   18.0        Javanicolide D   CHEMBL503843
# 11  21.0        Javanicoside B   CHEMBL503591
# 12  22.0        Javanicoside C   CHEMBL446883
# 13  23.0        Javanicoside D   CHEMBL451166
# 14  24.0        Javanicoside E   CHEMBL508819
# 15  25.0        Javanicoside F   CHEMBL510116
# 16  33.0        Yadanzioside A  CHEMBL2367704
# 18  35.0        Yadanzioside C   CHEMBL499465
# 19  36.0        Yadanzioside E  CHEMBL2367698
# 20  37.0        Yadanzioside F   CHEMBL509907
# 21  38.0        Yadanzioside G  CHEMBL2368538
# 22  39.0        Yadanzioside I   CHEMBL506706
# 24  43.0        Yadanzioside N  CHEMBL2368539
# ...

# %%
df.to_csv("EDA READY JAVANICA.csv", index= False)

# %%
def activity_level(pic50):
    
    if pic50 >= 6:
        return "High"
    
    elif pic50 <= 5:
        return "Low"
    
    else:
        return "Intermediate"

df["Activity_Level"] = df["pIC50"].apply(activity_level)
df
# Out:
#        0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1.0            Bruceine A   CHEMBL250451
# 1    2.0            Bruceine B   CHEMBL140809
# 2    3.0            Bruceine C   CHEMBL455759
# 3    4.0            Bruceine D   CHEMBL477693
# 6   10.0            Bruceine J   CHEMBL399970
# 7   17.0        Javanicolide C   CHEMBL443898
# 8   18.0        Javanicolide D   CHEMBL503843
# 11  21.0        Javanicoside B   CHEMBL503591
# 12  22.0        Javanicoside C   CHEMBL446883
# 13  23.0        Javanicoside D   CHEMBL451166
# 14  24.0        Javanicoside E   CHEMBL508819
# 15  25.0        Javanicoside F   CHEMBL510116
# 16  33.0        Yadanzioside A  CHEMBL2367704
# 18  35.0        Yadanzioside C   CHEMBL499465
# 19  36.0        Yadanzioside E  CHEMBL2367698
# 20  37.0        Yadanzioside F   CHEMBL509907
# 21  38.0        Yadanzioside G  CHEMBL2368538
# 22  39.0        Yadanzioside I   CHEMBL506706
# 24  43.0        Yadanzioside N  CHEMBL2368539
# ...

# %%
median_value = df["pIC50"].median()

def activity_group(pic50):
    
    if pic50 >= median_value:
        return "Higher Activity"
    else:
        return "Lower Activity"

df["Activity_Group"] = df["pIC50"].apply(activity_group)
df
# Out:
#        0 CHEMICAL CONSTITUENTS      ChEMBL_ID  \
# 0    1.0            Bruceine A   CHEMBL250451
# 1    2.0            Bruceine B   CHEMBL140809
# 2    3.0            Bruceine C   CHEMBL455759
# 3    4.0            Bruceine D   CHEMBL477693
# 6   10.0            Bruceine J   CHEMBL399970
# 7   17.0        Javanicolide C   CHEMBL443898
# 8   18.0        Javanicolide D   CHEMBL503843
# 11  21.0        Javanicoside B   CHEMBL503591
# 12  22.0        Javanicoside C   CHEMBL446883
# 13  23.0        Javanicoside D   CHEMBL451166
# 14  24.0        Javanicoside E   CHEMBL508819
# 15  25.0        Javanicoside F   CHEMBL510116
# 16  33.0        Yadanzioside A  CHEMBL2367704
# 18  35.0        Yadanzioside C   CHEMBL499465
# 19  36.0        Yadanzioside E  CHEMBL2367698
# 20  37.0        Yadanzioside F   CHEMBL509907
# 21  38.0        Yadanzioside G  CHEMBL2368538
# 22  39.0        Yadanzioside I   CHEMBL506706
# 24  43.0        Yadanzioside N  CHEMBL2368539
# ...

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='Activity_Group', data=df, edgecolor='black')

plt.xlabel('Activity_Group', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_Activity_Group2.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x='MW', y='LogP', data=df, hue='Activity_Group', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP2.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'Activity_Group', y = 'pIC50', data = df)

plt.xlabel('Activity_Group', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_ic502.pdf')

# %%
def mannwhitney(descriptor):

    from scipy.stats import mannwhitneyu

    # select needed columns
    selection = [descriptor, 'Activity_Group']
    df_selected = df[selection]

    # split groups
    high = df_selected[df_selected.Activity_Group == 'High'][descriptor]
    low = df_selected[df_selected.Activity_Group == 'Low'][descriptor]

    # run test
    stat, p = mannwhitneyu(high, low)

    # interpretation
    alpha = 0.05
    if p > alpha:
        interpretation = 'Same distribution (fail to reject H0)'
    else:
        interpretation = 'Different distribution (reject H0)'

    # results table
    results = pd.DataFrame({
        'Descriptor': descriptor,
        'Statistics': stat,
        'p-value': p,
        'alpha': alpha,
        'Interpretation': interpretation
    }, index=[0])

    return results

# %%
mannwhitney('pIC50')
# Out:
# C:\Users\Monsruti Devi\AppData\Local\Temp\ipykernel_15420\1951473503.py:14: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   stat, p = mannwhitneyu(high, low)
#   Descriptor  Statistics  p-value  alpha                      Interpretation
# 0      pIC50         NaN      NaN   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'Activity_Group', y = 'MW', data = df)

plt.xlabel('Activity_Group', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW2.pdf')

# %%
mannwhitney('MW')
# Out:
# C:\Users\Monsruti Devi\AppData\Local\Temp\ipykernel_15420\1951473503.py:14: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   stat, p = mannwhitneyu(high, low)
#   Descriptor  Statistics  p-value  alpha                      Interpretation
# 0         MW         NaN      NaN   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'Activity_Group', y = 'LogP', data = df)

plt.xlabel('Activity_Group', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP2.pdf')

# %%
mannwhitney('LogP')
# Out:
# C:\Users\Monsruti Devi\AppData\Local\Temp\ipykernel_15420\1951473503.py:14: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   stat, p = mannwhitneyu(high, low)
#   Descriptor  Statistics  p-value  alpha                      Interpretation
# 0       LogP         NaN      NaN   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'Activity_Group', y = 'HBD', data = df)

plt.xlabel('Activity_Group', fontsize=14, fontweight='bold')
plt.ylabel('HBD', fontsize=14, fontweight='bold')

plt.savefig('HBD2.pdf')

# %%
mannwhitney('HBD')
# Out:
# C:\Users\Monsruti Devi\AppData\Local\Temp\ipykernel_15420\1951473503.py:14: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   stat, p = mannwhitneyu(high, low)
#   Descriptor  Statistics  p-value  alpha                      Interpretation
# 0        HBD         NaN      NaN   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'Activity_Group', y = 'HBA', data = df)

plt.xlabel('Activity_Group', fontsize=14, fontweight='bold')
plt.ylabel('HBA', fontsize=14, fontweight='bold')

plt.savefig('plot_HBA2.pdf')

# %%
mannwhitney('HBA')
# Out:
# C:\Users\Monsruti Devi\AppData\Local\Temp\ipykernel_15420\1951473503.py:14: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   stat, p = mannwhitneyu(high, low)
#   Descriptor  Statistics  p-value  alpha                      Interpretation
# 0        HBA         NaN      NaN   0.05  Different distribution (reject H0)

# %%
! zip -r results.zip . -i *.csv *.pdf
# Out:
# 'zip' is not recognized as an internal or external command,
# operable program or batch file.
